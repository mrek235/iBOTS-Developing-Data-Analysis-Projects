# %%
import glob
import numpy as np
import pandas as pd
import argparse
from pathlib import Path 
parser =argparse.ArgumentParser('Feed me Path')

parser.add_argument('input_path',type=str,help = 'Input path for CSV files, Path must finish with \\ ')

args = parser.parse_args()

task_data_path = Path(args.input_path)

task_data_pattern = str(task_data_path / 'trial*.csv')
task_csvs = glob.glob(task_data_pattern)

csv_list = []
for csv in task_csvs:
    current_csv = pd.read_csv(csv)
    csv_list.append(current_csv)

task_df = pd.concat(csv_list)
task_df['Path'] = task_csvs
task_df.to_csv('task_data.csv')

# %%
# Out:
# C:\Users\mreki\AppData\Local\Temp\ipykernel_16068\2892177123.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Out:
#     trial  contrast_left  contrast_right  gocue_time  \
# 0       1            100              50    0.597817
# 0       2              0               0    0.728051
# 0       3              0               0    0.417442
# 0       4              0               0    0.683247
# 0       5              0               0    0.418173
# ..    ...            ...             ...         ...
# 0     386            100               0         NaN
# 0     387              0              25         NaN
# 0     388              0              25         NaN
# 0     389            100              25         NaN
# 0     390              0              50         NaN
#
#                                                  Path
# 0   C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# 0   C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# 0   C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# 0   C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# ...

# %%
import pandas
from pathlib import Path

performance_path = Path('C:\\Users\\mreki\\iBOTS-Developing-Data-Analysis-Projects\\session2\\data\\processed\\performance_data.csv')
task_path = Path('C:\\Users\\mreki\\iBOTS-Developing-Data-Analysis-Projects\\session2\\data\\processed\\task_data.csv')

perf_df = pd.read_csv(performance_path)
perf_df = perf_df[['']].rename({'Path':'performance_path'})
task_df = pd.read_csv(task_path)
task_df = task_df[['contrast_left','contrast_right','gocue_time','Path']].rename({'Path':'task_path'},axis=1)

joined_df = pd.concat([task_df, perf_df], axis=1)

joined_df
# Out:
#      trial  contrast_left  contrast_right  gocue_time  \
# 0        1            100              25    0.722770
# 1        2              0               0    0.698894
# 2        3              0               0    0.738808
# 3        4              0               0    0.738710
# 4        5            100             100    0.653391
# ..     ...            ...             ...         ...
# 385    386            100               0         NaN
# 386    387              0              25         NaN
# 387    388              0              25         NaN
# 388    389            100              25         NaN
# 389    390              0              50         NaN
#
#                                              task_path  Unnamed: 0  trial  \
# 0    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...           0      1
# 1    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...           0      2
# 2    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...           0      3
# ...

# %%
# Out:
#      Unnamed: 0  trial  response_type  response_time  feedback_time  \
# 0             0      1            1.0       0.925752       0.973975
# 1             0      2            0.0       2.204102       2.236523
# 2             0      3           -1.0       0.967406       0.967406
# 3             0      4            0.0       2.249045       2.287538
# 4             0      5            1.0       1.509495       1.509495
# ..          ...    ...            ...            ...            ...
# 385           0    386            NaN            NaN            NaN
# 386           0    387            NaN            NaN            NaN
# 387           0    388            NaN            NaN            NaN
# 388           0    389            NaN            NaN            NaN
# 389           0    390            NaN            NaN            NaN
#
#      feedback_type  reaction_time  reaction_type  \
# 0              1.0          150.0            1.0
# ...

# %%
task_df
# Out:
#      trial  contrast_left  contrast_right  gocue_time  \
# 0        1            100              25    0.722770
# 1        2              0               0    0.698894
# 2        3              0               0    0.738808
# 3        4              0               0    0.738710
# 4        5            100             100    0.653391
# ..     ...            ...             ...         ...
# 385    386            100               0         NaN
# 386    387              0              25         NaN
# 387    388              0              25         NaN
# 388    389            100              25         NaN
# 389    390              0              50         NaN
#
#                                              task_path
# 0    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# 1    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# 2    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# 3    C:\Users\mreki\iBOTS-Developing-Data-Analysis-...
# ...
