# %%
# !python ../clis/greet_user.py -h
# Out:
# usage: greet_user.py [-h] name
#
# Greet the user
#
# positional arguments:
#   name        Name of the user
#
# options:
#   -h, --help  show this help message and exit

# %%
# !python ../clis/greet_user.py Mo
# Out:
# Hello, Mo!

# %%
import numpy as np

# %%
np.load('C:\\Users\mreki\iBOTS-Developing-Data-Analysis-Projects\session2\data\processed\output_std.csv.npy')
# Out:
# array([-3.24446913e-02,  1.52538152e+00, -2.59979242e-01,  4.44357988e-01,
#        -2.54371534e-01,  1.49975452e+00,  1.42997716e+00, -3.01816119e-01,
#         1.49800136e+00,  7.72738130e-01,  1.87449148e+00, -1.19485505e+00,
#         9.96698756e-01,  1.17902777e+00, -8.56233733e-01, -9.97360425e-01,
#         2.17178434e-01, -7.84240386e-01, -6.16518410e-01, -4.66484736e-01,
#        -2.59229096e+00, -6.09005988e-01, -1.34042016e-01,  8.25372162e-01,
#         1.00582364e+00,  2.25121536e-01, -1.10681900e-01, -3.93973861e-01,
#        -5.42219255e-01, -4.11397223e-02, -9.85086529e-01,  1.54582573e-01,
#        -1.38414966e+00,  1.15458992e+00,  1.48429911e+00,  2.08760996e+00,
#         3.06791388e-01, -8.17628574e-01,  1.36686425e+00,  2.21719077e+00,
#         4.53986079e-01, -1.06773894e+00, -1.11149727e-02,  1.52941751e+00,
#        -2.94069035e-01,  6.33305341e-01,  7.68572692e-01,  3.68901356e-01,
# ...

# %%
np.load('C:\\Users\mreki\iBOTS-Developing-Data-Analysis-Projects\session2\data\processed\output_norm.csv.npy')
# Out:
# array([0.53301309, 0.77227186, 0.4980672 , 0.60624284, 0.49892846,
#        0.76833594, 0.75761918, 0.49164168, 0.76806668, 0.65667711,
#        0.82588992, 0.35448428, 0.69107411, 0.71907711, 0.40649144,
#        0.38481649, 0.57135147, 0.41754854, 0.44330812, 0.46635105,
#        0.13985906, 0.44446192, 0.51740927, 0.66476091, 0.69247556,
#        0.57257141, 0.52099703, 0.47748763, 0.45471936, 0.53167767,
#        0.38670158, 0.56173768, 0.32541146, 0.71532383, 0.76596222,
#        0.85862173, 0.58511467, 0.41242061, 0.74792598, 0.8785234 ,
#        0.60772157, 0.37400741, 0.53628902, 0.77289173, 0.49283152,
#        0.63526233, 0.65603736, 0.59465383, 0.455137  , 0.34399563,
#        0.64295962, 0.78264221, 0.61807975, 0.3462327 , 0.47185043,
#        0.73875558, 0.53288308, 0.38902205, 0.57216528, 0.49459106,
#        0.55312601, 0.42617632, 0.70856963, 0.53843543, 0.52429508,
#        0.66898833, 0.58649613, 0.72320907, 0.80085942, 0.86249527,
# ...
